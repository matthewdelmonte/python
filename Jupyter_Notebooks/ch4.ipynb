# %% [markdown]
# # Chapter 4 Linear Algebra
# ---

# %% [markdown]
# ## PIP Package Installs

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/homebrew/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 5.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pooch
# Out:
# Collecting pooch
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/homebrew/lib/python3.11/site-packages (from pooch) (4.2.2)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from pooch) (24.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/homebrew/lib/python3.11/site-packages (from pooch) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2024.7.4)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: pooch
# Successfully installed pooch-1.8.2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Fitting Polynomials with NumPy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate two random vectors
v1 = np.random.rand(10)
v2 = np.random.rand(10)

# Create a sequence of equally separated values
sequence = np.linspace(v1.min(), v1.max(), num = len(v1) * 10)

# Fit the data to polynomial fit data with 4 degrees of the polynomial
coefs = np.polyfit(v1, v2, 3)

# Evaluate polynomial on given sequence
polynomial_sequence = np.polyval(coefs, sequence)

# plot the polynomial curve
plt.plot(sequence, polynomial_sequence)

# Show plot
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Determinant

# %%
import numpy as np

# Create matrix using NumPy
mat = np.asmatrix(([2,4], [5,7]))
print("Matrix:\n", mat)

# Calculate determinant
det = np.linalg.det(mat)
print("Determinant: {:.2f}".format(det))
# Out:
# Matrix:
#  [[2 4]
#  [5 7]]
# Determinant: -6.00

# %% [markdown]
# ## Finding the rank of a matrix

# %%
# import required libraries
import numpy as np
from numpy.linalg import matrix_rank

# Create a matrix
mat = np.array([[5,3,1], [5,3,1], [1, 0, 5]])

# Compute rank of matrix
print("Matrix: \n", mat)
print("Rank:", matrix_rank(mat))
# Out:
# Matrix:
#  [[5 3 1]
#  [5 3 1]
#  [1 0 5]]
# Rank: 2

# %% [markdown]
# ## Matrix inverse using NumPy

# %%
import numpy as np

# Create matrix using NumPy
mat = np.asmatrix([[2, 4], [5, 7]])
print("Input Matrix:\n", mat)

# Find matrix inverse
inverse = np.linalg.inv(mat)
print("Inverse:\n", inverse)
# Out:
# Input Matrix:
#  [[2 4]
#  [5 7]]
# Inverse:
#  [[-1.16666667  0.66666667]
#  [ 0.83333333 -0.33333333]]

# %% [markdown]
# ## Solving linear equations using NumPy

# %%
# Create matrix A and Vector B using NumPy
A = np.asmatrix([[1, 1], [3 , 2]])
print("Matrix A:\n", A)

B = np.array([200, 450])
print("Vector B:", B)

# Solve linear equations
solution = np.linalg.solve(A, B)
print("Solution vector x:", solution)

# Check th3 solution
print("Result:", np.dot(A, solution))
# Out:
# Matrix A:
#  [[1 1]
#  [3 2]]
# Vector B: [200 450]
# Solution vector x: [ 50. 150.]
# Result: [[200. 450.]]

# %% [markdown]
# ## Decomposing a matrix using SVD "Singular Value Decomposition"

# %%
import numpy as np
from scipy.linalg import svd

# Create a matrix
mat = np.array([[5, 3, 1], [5, 3, 0], [1, 0, 5]])

# Perform matrix decomposition using SVD
U, Sigma, V_transpose = svd(mat)

print("Left Singular matrix:\n", U)
print("Diagonal Matrix:\n", Sigma)
print("Right Singular Matrix\n", V_transpose)
# Out:
# Left Singular matrix:
#  [[-0.70097269 -0.06420281 -0.7102924 ]
#  [-0.6748668  -0.26235919  0.68972636]
#  [-0.23063411  0.9628321   0.14057828]]
# Diagonal Matrix:
#  [8.42757145 4.89599358 0.07270729]
# Right Singular Matrix
#  [[-0.84363943 -0.48976369 -0.2200092 ]
#  [-0.13684207 -0.20009952  0.97017237]
#  [ 0.51917893 -0.84858218 -0.10179157]]

# %% [markdown]
# ## Eigenvectors and Eigenvalues using NumPy

# %%
import numpy as np
# Create matrix using NumPy
mat = np.asmatrix([[2, 5], [5, 7]])
print("Matrix:\n", mat)

# Calculate the eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(mat)
print("Eigenvalues:\n", eigenvalues)
print("Eigenvectors:\n", eigenvectors)
# Out:
# Matrix:
#  [[2 5]
#  [5 7]]
# Eigenvalues:
#  [-1.09016994 10.09016994]
# Eigenvectors:
#  [[-0.85065081 -0.52573111]
#  [ 0.52573111 -0.85065081]]

# %% [markdown]
# ## Generating Random Numbers

# %%
import numpy as np

# Create an array with random values
random_mat = np.random.random((3, 3))
print("Random matrix:\n", random_mat)
# Out:
# Random matrix:
#  [[0.64511535 0.876437   0.68416265]
#  [0.44421198 0.71486214 0.15113489]
#  [0.22201793 0.6558256  0.38772745]]

# %% [markdown]
# ### Binomial distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create an numpy vector of size 5000 with value 0
cash_balance = np.zeros(5000)

cash_balance[0] = 500

# Generate random numbers using Binomial
samples = np.random.binomial(9, 0.5, size = len(cash_balance))

# Update the cash balance
for i in range(1, len(cash_balance)):
    if samples[i] < 5:
        cash_balance[i] = cash_balance[i - 1] -1
    else:
        cash_balance[i] = cash_balance[i - 1] + 1
        
# Plot the updated cash balance
plt.plot(np.arange(len(cash_balance)), cash_balance)
plt.show()

# %% [markdown]
# ## Normal Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_size = 225000

# Generate random values sample using normal distribution
sample = np.random.normal(size = sample_size)

# Create Histogram
n, bins, patch_list = plt.hist(sample, int(np.sqrt(sample_size)), density = True)

# Set parameters
mu, sigma = 0, 1

x = bins
y = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2))

# Plot line plot (or bell curve)
plt.plot(x, y, color = 'red', lw = 2)
plt.show()

# %% [markdown]
# ## Testing normality of data using SciPy

# %%
import numpy as np

# Create small, medium, and large sample for normality test
small_sample = np.random.normal(loc = 100, scale = 60, size = 15)
medium_sample = np.random.normal(loc = 100, scale = 60, size = 100)
large_sample = np.random.normal(loc = 100, scale = 60, size = 1000)

# Histogram for small
import seaborn as sns
import matplotlib.pyplot as plt

# Create distribution plot
sns.histplot(large_sample)

plt.show()

# %% [markdown]
# ### Test using Shapiro-Wilk, Anderson-Darling and D'Agostino and Pearson's Tests

# %%
from scipy.stats import shapiro, anderson, normaltest

# Create small, medium, and large sample for normality test
small_sample = np.random.normal(loc = 100, scale = 60, size = 15)
medium_sample = np.random.normal(loc = 100, scale = 60, size = 100)
large_sample = np.random.normal(loc = 100, scale = 60, size = 1000)


# Apply Shapiro-Wilk test
print("Shapiro-Wilk Test for Small Sample: ", shapiro(small_sample))
print("Shapiro-Wilk Test for Medium Sample: ", shapiro(medium_sample))
print("Shapiro-Wilk Test for Large Sample: ", shapiro(large_sample))
print()

# Apply Anderson-Darling test
print("Anderson-Darling Test for Small Sample: ", anderson(small_sample))
print("Anderson-Darling Test for Medium Sample: ", anderson(medium_sample))
print("Anderson-Darling Test for Large Sample: ", anderson(large_sample))
print()

# Apply D'Agostino and Pearson's test
print("D'Agostino and Pearson's Test for Small Sample: ", normaltest(small_sample))
print("D'Agostino and Pearson's Test for Medium Sample: ", normaltest(medium_sample))
print("D'Agostino and Pearson's Test for Large Sample: ", normaltest(large_sample))
# Out:
# Shapiro-Wilk Test for Small Sample:  ShapiroResult(statistic=np.float64(0.9513882597181879), pvalue=np.float64(0.5465770550866711))
# Shapiro-Wilk Test for Medium Sample:  ShapiroResult(statistic=np.float64(0.9895387823013893), pvalue=np.float64(0.6274113297923851))
# Shapiro-Wilk Test for Large Sample:  ShapiroResult(statistic=np.float64(0.998729810140079), pvalue=np.float64(0.7085686643859471))
#
# Anderson-Darling Test for Small Sample:  AndersonResult(statistic=np.float64(0.3371974306608134), critical_values=array([0.498, 0.568, 0.681, 0.794, 0.945]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=np.float64(104.72435072255031), scale=np.float64(71.87956153715538))
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
# Anderson-Darling Test for Medium Sample:  AndersonResult(statistic=np.float64(0.19140645029355596), critical_values=array([0.555, 0.632, 0.759, 0.885, 1.053]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=np.float64(99.92647459179177), scale=np.float64(53.36241308508514))
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
# Anderson-Darling Test for Large Sample:  AndersonResult(statistic=np.float64(0.31735528953299763), critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=np.float64(100.04263986495317), scale=np.float64(57.6756653168498))
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
#
# D'Agostino and Pearson's Test for Small Sample:  NormaltestResult(statistic=np.float64(1.2891357553043599), pvalue=np.float64(0.5248893095082037))
# D'Agostino and Pearson's Test for Medium Sample:  NormaltestResult(statistic=np.float64(0.34644715906116275), pvalue=np.float64(0.8409495747132874))
# D'Agostino and Pearson's Test for Large Sample:  NormaltestResult(statistic=np.float64(0.7712310696657558), pvalue=np.float64(0.6800319240151387))
# /opt/homebrew/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=15 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %% [markdown]
# ## Creating a masked array using the numpy.ma subpackage

# %%
import numpy as np
from scipy.datasets import face
import matplotlib.pyplot as plt

face_image = face()
mask_random_array = np.random.randint(0, 3, size = face_image.shape)

fig, ax = plt.subplots(nrows = 2, ncols = 2)

# Display the Original Image
plt.subplot(2, 2, 1)
plt.imshow(face_image)
plt.title("Original Image")
plt.axis('off')

# Display masked array
masked_array = np.ma.array(face_image, mask = mask_random_array)
plt.subplot(2, 2, 2)
plt.title("Masked Array")
plt.imshow(masked_array)
plt.axis('off')

# Log operation on original image
plt.subplot(2, 2, 3)
plt.title("Log Operation on Original")
plt.imshow(np.ma.log(face_image).astype('uint8'))
plt.axis('off')

# Log operation on masked array
plt.subplot(2, 2, 4)
plt.title("Log Operation on Masked")
plt.imshow(np.ma.log(masked_array).astype('uint8'))
plt.axis('off')

# Display the plot
plt.show()
# Out:
# Downloading file 'face.dat' from 'https://raw.githubusercontent.com/scipy/dataset-face/main/face.dat' to '/Users/matthew/Library/Caches/scipy-data'.
