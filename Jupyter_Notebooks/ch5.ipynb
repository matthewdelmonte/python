# %% [markdown]
# # Chapter 5 Data Visualization
# ---

# %% [markdown]
# ## PIP Package Installs

# %%
# %pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 71.0 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 96.1 MB/s eta 0:00:00
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install bokeh
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install bokeh_sampledata
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 11.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 475.6 kB/s eta 0:00:00 0:00:01m
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Visualization using Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the data
data = np.linspace(0, 20)

# Draw the plot
plt.plot(data, data + 0.5, label = 'linear')

# Display the plot
plt.show()

# %% [markdown]
# ## Charts with Accessories

# %%
import matplotlib.pyplot as plt

# Create the data
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]

plt.figure(figsize = (8, 8))

# Let's plot the data
plt.plot(x, y, label = 'Series-1', color = 'blue')

# Create the data
x = [2, 4, 6, 8, 10, 12]
y = [15, 29, 32, 33, 38, 55]

# Let's plot the data
plt.plot(x, y, label = 'Series-2', color = 'red')

# Add x label on x-axis
plt.xlabel("X-label")

# Add y label on x-axis
plt.ylabel("Y-label")

# Append the title to graph
plt.title("Multiple Python Line Graph")

# Add legend to the graph
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
import matplotlib.pyplot as plt

# Create the data
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]

# Draw the scatter chart
plt.scatter(x, y, c = 'blue', marker = '.', alpha = 0.5)

# Append the label on X-axis
plt.xlabel("X-label")

# Append the label on Y-axis
plt.ylabel("Y-label")

# Add the title to graph
plt.title("Scatter Chart Sample")

# Display the chart
plt.show()

# %% [markdown]
# ## Line Plot

# %%
import matplotlib.pyplot as plt

# Create the data
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]

# Draw the line chart
plt.plot(x, y)

# Append the label on X-axis
plt.xlabel("X-label")

# Append the label on Y-axis
plt.ylabel("Y-label")

# Append the title to chart
plt.title("Line Chart Sample")

# Display the chart
plt.show()

# %% [markdown]
# ## Pit Plot

# %%
import matplotlib.pyplot as plt

# Create the data
subjects = ["Mathematics", "Science", "Communication Skills", "Computer Application"]
scores = [85, 62, 57, 92]

# Plot the Pie plot
plt.pie(scores,
        labels = subjects,
        colors = ['r', 'g', 'b', 'y'],
        startangle = 90,
        shadow = True,
        explode = (0, 0.1, 0, 0),
        autopct = '%1.1f%%')

# Add title to graph
plt.title("Student Performance")

# Draw the chart
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
import matplotlib.pyplot as plt

# Create the data
movie_ratings = [1, 2, 3, 4, 5]
rating_counts = [21, 45, 72, 89, 42]

# Plot the data
plt.bar(movie_ratings, rating_counts, color = 'blue')

# Add X Label on X-axis
plt.xlabel("Movie Ratings")

# Add Y Label on Y-axis
plt.ylabel("Rating Frequency")

# Add a title to graph
plt.title("Movie Rating Distribution")

# Show the plot
plt.show()

# %% [markdown]
# ## Histogram Plot

# %%
import matplotlib.pyplot as plt

# Create the data
employee_age = [21, 28, 32, 34, 35, 35, 37, 42, 47, 55]

# Create bins for histogram
bins = [20, 30, 40, 50, 60]

# Plot the histogram
plt.hist(employee_age, bins, rwidth = 0.2)

# Add X Label on X-axis
plt.xlabel("Employee Age")

# Add Y Label on Y-axis
plt.ylabel("Frequency")

# Add title to graph
plt.title("Employee Age Distribution")

# Show the plot
plt.show()

# %% [markdown]
# ## Bubble Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set figure size
plt.figure(figsize = (8, 5))

# Create the data
countries = ['Quatar', 'Luxembourg', 'Singapore', 'Brunei', 'Ireland', 'Norway', 'UAE', 'Kuwait']
populations = [2781682, 625978, 5638676, 437479, 4920455, 5461180, 9890400, 4136528]
gdp_per_capita = [124930, 109190, 90250, 79990, 78730, 75270, 69990, 68360]

# scale GDP per capita income to shoot the bubbles in the graph
scaled_gdp_per_capita = np.divide(gdp_per_capita, 80)

colors = np.random.rand(8)

# Draw the scatter diagram
plt.scatter(countries, populations, s=scaled_gdp_per_capita, c=colors, cmap="Blues", edgecolors="grey", alpha=0.5)

# Add X Label on X-axis
plt.xlabel("Countries")

# Add Y Label on Y-axis
plt.ylabel("Countries")

# Add title to graph
plt.title("Bubble Chart")

# Rotate x label for cleear visualization
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# # Pandas Plotting

# %% [markdown]
# ## Scatter Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a Dataframe
df = pd.DataFrame({
    'name': ['Ajay', 'Malala', 'Abhijeet', 'Yming', 'Desilva', 'Lisa'],
    'age': [22, 72, 25, 19, 42, 38],
    'gender': ['M', 'F', 'M', 'M', 'M', 'F'],
    'country': ['India', 'Pakistan', 'Bangladesh', 'China', 'Srilanka', 'UK'],
    'income': [2500, 3800, 3300, 2100, 4500, 5500]
})

# Create a scatter plot
df.plot(kind='scatter', x='age', y='income', color='red', title='Age vs Income')

plt.show()

# %% [markdown]
# ## Bar Plot

# %%
import pandas as pd

# Create a bar plot
df.plot(kind='bar', x='name', y='age', color='blue')

plt.show()

# %% [markdown]
# # Seaborn Advanced Visualizations

# %% [markdown]
# ## Lmplot with Regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create Dataframe
df = pd.DataFrame({
    'x': [1, 3, 5, 7, 9, 11],
    'y': [10, 25, 35, 33, 41, 59]
})

# Create a lmplot
sns.lmplot(x='x', y='y', data=df)

plt.show()

# %% [markdown]
# ## Scatter plot

# %%
# Load the dataset
df = pd.read_csv("../Data/HR_comma_sep.csv")

# Create lmplot
sns.lmplot(x='satisfaction_level', y='last_evaluation', data=df, fit_reg=False,  hue='left')

plt.show()

# %% [markdown]
# ## Bar Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create Dataframe
df=pd.DataFrame({
    'x': ['P', 'Q', 'R', 'S', 'T', 'U'],
    'y': [10, 25, 35, 33, 41, 59]
})

# Create Lmplot
sns.barplot(x='x', y='y', data=df)

plt.show()

# %% [markdown]
# ## Distribution Plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import dataset
df = pd.read_csv("../Data/HR_comma_sep.csv")

# Create a distribution plot (also know as a Histogram)
sns.displot(df['satisfaction_level'], kde=True)

plt.show()

# %% [markdown]
# ## Box Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import the dataset
df = pd.read_csv('../Data/HR_comma_sep.csv')

# Create the box plot
sns.boxplot(data=df[['satisfaction_level', 'last_evaluation']])

plt.show()

# %% [markdown]
# ## KDE Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import dataset
df = pd.read_csv('../Data/HR_comma_sep.csv')

# Create a desity plot
sns.kdeplot(df['satisfaction_level'])

plt.show()

# %% [markdown]
# ## Violin Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import dataset
df = pd.read_csv('../Data/HR_comma_sep.csv')

# Create violin plot
sns.violinplot(data=df[['satisfaction_level', 'last_evaluation']])

plt.show()

# %% [markdown]
# ## Count Plots

# %%
import pandas as pd
import seaborn as sns

# Import dataset
df = pd.read_csv('../Data/HR_comma_sep.csv')

# Create count plot
sns.countplot(x='salary', data=df, hue='left')

plt.show()

# %% [markdown]
# ## Joint Plots

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('../Data/HR_comma_sep.csv')

# Create Joint plot
sns.jointplot(x='satisfaction_level', y='last_evaluation', data=df, kind="kde")

plt.show()

# %% [markdown]
# ## Heatmaps

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Read iris data using load_dataset function
data = sns.load_dataset('iris')
print(data.head())

# Exclude non-numeric 'species' column
numeric_data = data.drop(columns=['species'])

# Find correlation
cor_matrix = numeric_data.corr()

# Create heatmap
sns.heatmap(cor_matrix, annot=True, cmap='YlGnBu')

plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Pair Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load iris data using load_dataset() function
data = sns.load_dataset('iris')

# Create a pair plot
sns.pairplot(data)

plt.figure(figsize=(8, 8))

plt.show()

# %% [markdown]
# # Bokeh Library Visualizations

# %% [markdown]
# ## Plotting a simple graph

# %%
from bokeh.plotting import figure, output_notebook, show

# Create the data
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]

# Output to notebook
output_notebook()

# Instantiate a figure
fig = figure(width = 500, height = 350)

# Create scatter circle marker plot by rendering the circles
fig.scatter(x, y, size = 10, color = 'red', alpha = 0.7)

# Show the plot
show(fig)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="abca596f-7621-42ca-8417-82c832856035">Loading BokehJS ...</span>
#     </div>
#   <div id="bfbfab2c-2b5e-46ea-bd23-83a9d6a5bfac" data-root-id="p1182" style="display: contents;"></div>

# %% [markdown]
# ## Glyphs

# %%
from bokeh.plotting import figure, output_notebook, show

# Create the data
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]

# Output to notebook
output_notebook()

# Instantiate a figure
p = figure(width = 500, height = 350)

# Create a line plot
p.line(x, y, line_width = 1, color = 'blue')

# Show the plot
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ae75c42f-c375-479e-a033-3ea44dcd4a6d">Loading BokehJS ...</span>
#     </div>
#   <div id="aba1d889-6913-4114-befc-9dc594e1e473" data-root-id="p1259" style="display: contents;"></div>

# %% [markdown]
# ## Layouts - Row, Column, Nested, Grid

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import row, column

# Import iris flower dataset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Instantiate a figure
fig1 = figure(width = 300, height = 300)
fig2 = figure(width = 300, height = 300)
fig3 = figure(width = 300, height = 300)

# Create scatter marker plot by render the circles(deprecated), using scatter method
fig1.scatter(df['petal_length'], df['sepal_length'], size=8, color='green', alpha=0.5)
fig2.scatter(df['petal_length'], df['sepal_length'], size=8, color='blue', alpha=0.5)
fig3.scatter(df['petal_length'], df['sepal_length'], size=8, color='red', alpha=0.5)

# Create row layout
row_layout = row(fig1, fig2, fig3)
col_layout = column(fig1, fig2, fig3)

print('Row Layout')
show(row_layout)
print('Column Layout')
show(col_layout)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cfc86779-54a6-4abb-9389-3e18b6e81d88">Loading BokehJS ...</span>
#     </div>
# Row Layout
#   <div id="ea378ed0-e53f-4e18-9a88-9a79fb45f3d1" data-root-id="p1654" style="display: contents;"></div>
# Column Layout
#   <div id="ef027e85-242b-49e7-a9be-860fa27eb012" data-root-id="p1655" style="display: contents;"></div>

# %% [markdown]
# ## Nested layout using row and column layouts

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import row, column

# Import iris flower dataset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Instantiate a figure
fig1 = figure(width = 300, height = 300)
fig2 = figure(width = 300, height = 300)
fig3 = figure(width = 300, height = 300)

# Create scatter marker plot by render the circles(deprecated), using scatter method
fig1.scatter(df['petal_length'], df['sepal_length'], size=8, color='green', alpha=0.5)
fig2.scatter(df['petal_length'], df['sepal_length'], size=8, color='blue', alpha=0.5)
fig3.scatter(df['petal_length'], df['sepal_length'], size=8, color='red', alpha=0.5)

# Create nested layout
nested_layout = row(fig1, column(fig2, fig3))

show(nested_layout)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a8f65802-bbb8-4165-85a8-440724163640">Loading BokehJS ...</span>
#     </div>
#   <div id="d47d8901-03fc-4fb9-bc60-e5d845d1133e" data-root-id="p1798" style="display: contents;"></div>

# %% [markdown]
# ## Multiple Plots

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import gridplot 

# Import iris flower dataset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Instantiate a figure
fig1 = figure(width = 300, height = 300)
fig2 = figure(width = 300, height = 300)
fig3 = figure(width = 300, height = 300)

# Create scatter marker plot by render the circles(deprecated), using scatter method
fig1.scatter(df['petal_length'], df['sepal_length'], size=8, color='green', alpha=0.5)
fig2.scatter(df['petal_length'], df['sepal_length'], size=8, color='blue', alpha=0.5)
fig3.scatter(df['petal_length'], df['sepal_length'], size=8, color='red', alpha=0.5)

# Create grid layout
grid_layout = gridplot([[fig1, fig2], [None, fig3]])

show(grid_layout)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c7f2461f-37e1-42ea-9eb3-56d7b4cfbc19">Loading BokehJS ...</span>
#     </div>
#   <div id="d2c18d3e-cb93-4c7c-93fa-d8bb379856e1" data-root-id="p1941" style="display: contents;"></div>

# %% [markdown]
# ## Interactions / hide click policy

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper

# Import iris flower dataset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Instantiate a figure object
fig = figure(width = 500, height = 350, title="Petal length vs. Petal Width", x_axis_label='petal_length', y_axis_label='petal_width')

# Create scatter merker plot by render the circles
for specie, color in zip(['setosa', 'virginica', 'versicolor'], ['blue', 'green', 'red']):
    data = df[df.species==specie]
    fig.scatter('petal_length', 'petal_width', size=8, color=color, alpha=0.7, legend_label=specie, source=data)

# Set the legend location and click policy
fig.legend.location = 'top_left'
fig.legend.click_policy = 'hide'

show(fig)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="da9f09a7-593a-432f-b289-8f4e2f735048">Loading BokehJS ...</span>
#     </div>
#   <div id="c43ccb01-7f39-4a21-8879-b0d7e7fa4841" data-root-id="p2297" style="display: contents;"></div>

# %% [markdown]
# ## Interactions / mute click policy

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper

# Import iris flower dataset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Instantiate a figure object
fig = figure(width = 500, height = 350, title="Petal length vs. Petal Width", x_axis_label='petal_length', y_axis_label='petal_width')

# Create scatter merker plot by render the circles
for specie, color in zip(['setosa', 'virginica', 'versicolor'], ['blue', 'green', 'red']):
    data = df[df.species==specie]
    fig.scatter('petal_length', 'petal_width', size=8, color=color, alpha=0.7, legend_label=specie, source=data, muted_color=color, muted_alpha=0.2)

# Set the legend location and click policy
fig.legend.location = 'top_left'
fig.legend.click_policy = 'mute'

show(fig)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c8a42380-9d02-46c6-b776-af12e566440a">Loading BokehJS ...</span>
#     </div>
#   <div id="cc6efb4b-358f-4854-94c5-afd73e62e9c5" data-root-id="p2387" style="display: contents;"></div>

# %% [markdown]
# ## Annotations

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper

# Import iris flower datasset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Create color mapper for categorical column
color_mapper = CategoricalColorMapper(factors=['setosa', 'virginica', 'versicolor'], palette=['blue', 'green', 'red'])

color_dict={
    'field': 'species',
    'transform': color_mapper
}

# Instantiate a figure object
p = figure(width=500, height=350, title="Petal Length Vs. Petal Width", x_axis_label='petal_length', y_axis_label='petal_width')

# Create scatter marker plot by render the circles(scatter, circles has been deprocated)
p.scatter('petal_length', 'petal_width', size=8, color=color_dict, alpha=0.5, legend_group='species', source=df)

# Set the legend location
p.legend.location = 'top_left'
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d184fd7b-0fbf-49f1-9867-4ce33726bac9">Loading BokehJS ...</span>
#     </div>
#   <div id="ff8aa678-6fd3-4624-9e0b-6a81085c42b7" data-root-id="p2678" style="display: contents;"></div>

# %% [markdown]
# ## Hover Tool

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper, HoverTool

# Import iris flower datasset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Create color mapper for categorical column
color_mapper = CategoricalColorMapper(factors=['setosa', 'virginica', 'versicolor'], palette=['blue', 'green', 'red'])

color_dict={
    'field': 'species',
    'transform': color_mapper
}

# Create hovertool and specify the hovering information
hover = HoverTool(tooltips=[('Species type', '@species'), ('IRIS Petal Length', '@petal_length'), ('IRIS Petal Width', '@petal_width')])

# Instantiate a figure object
p = figure(width=500, height=350, title="Petal Length Vs. Petal Width", x_axis_label='petal_length', y_axis_label='petal_width', tools=[hover, 'pan', 'wheel_zoom'])

# Create scatter marker plot by render the circles(scatter, circles has been deprocated)
p.scatter('petal_length', 'petal_width', size=8, color=color_dict, alpha=0.5, legend_group='species', source=df)

# Set the legend location
p.legend.location = 'top_left'

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a4d67a6c-498c-4394-81c1-ca0864bf5982">Loading BokehJS ...</span>
#     </div>
#   <div id="fa13b566-5204-4ca9-a055-60732ec9f023" data-root-id="p2738" style="display: contents;"></div>

# %% [markdown]
# # Widgets

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models.widgets import Panel, Tabs

# Import iris flower dataset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df

# output to notebook
output_notebook()

# Instantiate a figure
fig1 = figure(width=300, height=300)
fig2 = figure(width=300, height=300)

# Create scatter marker plot by render the circles
fig1.scatter(df['petal_length'], df['sepal_length'], size=8, color="green", alpha=0.5)
fig2.scatter(df['petal_length'], df['sepal_length'], size=8, color="blue", alpha=0.5)

# Create the panels
tab1 = Panel(child=fig1, title='tab1')
tab2 = Panel(child=fig2, title='tab2')

# Create tab by putting panels into it
tab_layout = Tabs(tabs=[tab1, tab2])

show(tab_layout)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from bokeh.plotting import figure, output_notebook, show
# ----> 2 from bokeh.models.widgets import Panel, Tabs
#       4 # Import iris flower dataset as pandas DataFrame
#       5 from bokeh.sampledata.iris import flowers as df
#
# ImportError: cannot import name 'Panel' from 'bokeh.models.widgets' (/opt/homebrew/lib/python3.11/site-packages/bokeh/models/widgets/__init__.py)
