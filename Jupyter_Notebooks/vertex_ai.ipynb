# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9boKY-0aMfE?si=YM_gq73cJtjNakZe" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
from IPython.display import YouTubeVideo

# Use the video ID directly
YouTubeVideo("88yQTzlmsiA", width=560, height=315)

# %%
from IPython.display import HTML, display
from urllib.parse import urlparse, parse_qs

def display_youtube_video(url: str) -> None:
    # Check if the URL is already in the embed format
    youtube_video_embed_url = url.split("?")[0]  # Remove unnecessary query parameters

    print(youtube_video_embed_url)  # Debugging: Print the final embed URL

    # Create HTML code to directly embed video
    youtube_video_embed_html_code = f"""
    <iframe width="560" height="315" src="{youtube_video_embed_url}"
    title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; 
    clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen>
    </iframe>
    """

    # Display embedded YouTube video
    display(HTML(youtube_video_embed_html_code))

# Pass the embed URL directly
display_youtube_video("https://www.youtube.com/embed/88yQTzlmsiA?si=Dexmqs0B6jvuPQdx")
# Out:
# https://www.youtube.com/embed/88yQTzlmsiA
#     <iframe width="560" height="315" src="https://www.youtube.com/embed/88yQTzlmsiA"
#     title="YouTube video player" frameborder="0" allow="accelerometer; autoplay;
#     clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen>
#     </iframe>
